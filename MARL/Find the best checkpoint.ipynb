# %%
import os
import time

import pandas as pd
import numpy as np
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import re

from copo import pretty_print

# %matplotlib inline

# %%
EVALUATE_RESULTS_PATH = "./formal_evaluate_results"

os.listdir(EVALUATE_RESULTS_PATH)
# Out:
# ['.DS_Store',
#  '1011_ccppo_concat_evaluate_results.csv',
#  '1003_copo_formal_evaluate_results.csv',
#  '1003_ippo_evaluate_results.csv',
#  '1012_ccppo_mf_evaluate_results.csv']

# %%
eval_df = []

algo_set = set()
env_set = set()

count = 0

for p in os.listdir(EVALUATE_RESULTS_PATH):
    match = re.search("(.*?)_evaluate_results.csv", p)
    
    if match:
        
        count += 1
        
        exp_name = match[1]
        
        full_p = os.path.abspath(os.path.join(EVALUATE_RESULTS_PATH, p))
        
        try:
            tmp = pd.read_csv(full_p)
        except Exception as e:
            print(full_p)
            raise e

        tmp["exp_name"] = exp_name
        tmp["model_index"] = p
        
        eval_df.append(tmp)
        
        print(f"[{count}] Processed the agent: ", exp_name)
    else:
        print(p, " not exists!")
                
eval_df = pd.concat(eval_df)
# Out:
# .DS_Store  not exists!
# [1] Processed the agent:  1011_ccppo_concat
# [2] Processed the agent:  1003_copo_formal
# [3] Processed the agent:  1003_ippo
# [4] Processed the agent:  1012_ccppo_mf

# %%
for env_short_name in ["Inter", "Round", "Parking", "Bottle", "Tollgate"]:
    eval_df.loc[
        [env_short_name in item for item in eval_df.env],
        "env"
    ] = env_short_name
    
eval_df.loc[
    ["MetaDrive" in item for item in eval_df.env],
    "env"
] = "PGMap"

# %% [markdown]
# ## Find the best checkpoint for each env and algo.
#
# That is applying maximum operation across all seeds and checkpoints for a given env and algo.

# %%
for env, gb_env in eval_df.groupby("env"):  # Each env
    for exp_name, gb in gb_env.groupby('exp_name'):  # Each algorithm
        
        best_checkpoint_value = float("-inf")
        best_checkpoint_data = None
        best_checkpoint_path = None
        
        for seed, seed_gb in gb.groupby("seed"):  # Each seed
            
            for path, ckpt_gb in seed_gb.groupby("path"):  # Find the best checkpoint
                
                val = ckpt_gb["success_rate"].mean()
                assert np.isscalar(val)
                
                if val > best_checkpoint_value:
                    best_checkpoint_value = val
                    best_checkpoint_data = ckpt_gb    
                    best_checkpoint_path = path
            
        print(f"For env={env}, algo={exp_name}, seed={seed}, we find {len(seed_gb.path.unique())} checkpoints and the best success rate is {best_checkpoint_value:.3f}")
        print(f"Path:\n{path}\n\n")
# Out:
# For env=Bottle, algo=1003_copo_formal, seed=12000, we find 6 checkpoints and the best success rate is 0.781
# Path:
# /home/zhpeng/CoPO/copo_code/copo/1003_copo/CoPO_CCMultiAgentBottleneckEnv_647d3_00045_45_env=CCMultiAgentBottleneckEnv,start_seed=12000,seed=0,use_centralized_critic=False,u_2022-10-05_17-22-51/checkpoint_625/checkpoint-625
#
#
# For env=Bottle, algo=1003_ippo, seed=12000, we find 4 checkpoints and the best success rate is 0.610
# Path:
# /home/zhenghao/CoPO/copo_code/copo/1003_ippo/IPPO_MultiAgentBottleneckEnv_ad347_00045_45_env=MultiAgentBottleneckEnv,start_seed=12000,seed=0_2022-10-04_01-25-13/checkpoint_625/checkpoint-625
#
#
# For env=Bottle, algo=1011_ccppo_concat, seed=12000, we find 4 checkpoints and the best success rate is 0.547
# Path:
# /home/zhenghao/CoPO/copo_code/copo/1011_ccppo_concat/CCPPOTrainerForMAOurEnvironment_CCMultiAgentBottleneckEnv_8533d_00044_44_counterfactual=True,env=CCMultiAgentBottleneckEnv,start_s_2022-10-11_19-33-16/checkpoint_625/checkpoint-625
#
#
# For env=Bottle, algo=1012_ccppo_mf, seed=12000, we find 4 checkpoints and the best success rate is 0.463
# Path:
# /home/zhenghao/CoPO/copo_code/copo/1012_ccppo_mf/CCPPOTrainerForMAOurEnvironment_CCMultiAgentBottleneckEnv_2700f_00044_44_counterfactual=True,env=CCMultiAgentBottleneckEnv,start_s_2022-10-12_21-38-05/checkpoint_625/checkpoint-625
#
#
# For env=Inter, algo=1003_copo_formal, seed=12000, we find 6 checkpoints and the best success rate is 0.861
# Path:
# /home/zhpeng/CoPO/copo_code/copo/1003_copo/CoPO_CCMultiAgentIntersectionEnv_647d3_00046_46_env=CCMultiAgentIntersectionEnv,start_seed=12000,seed=0,use_centralized_critic=Fal_2022-10-05_17-43-51/checkpoint_625/checkpoint-625
#
#
# For env=Inter, algo=1003_ippo, seed=12000, we find 4 checkpoints and the best success rate is 0.795
# Path:
# /home/zhenghao/CoPO/copo_code/copo/1003_ippo/IPPO_MultiAgentIntersectionEnv_ad347_00043_43_env=MultiAgentIntersectionEnv,start_seed=12000,seed=0_2022-10-04_01-12-16/checkpoint_625/checkpoint-625
#
#
# For env=Inter, algo=1011_ccppo_concat, seed=12000, we find 4 checkpoints and the best success rate is 0.807
# Path:
# /home/zhenghao/CoPO/copo_code/copo/1011_ccppo_concat/CCPPOTrainerForMAOurEnvironment_CCMultiAgentIntersectionEnv_8533d_00047_47_counterfactual=True,env=CCMultiAgentIntersectionEnv,sta_2022-10-11_19-58-05/checkpoint_625/checkpoint-625
#
#
# For env=Inter, algo=1012_ccppo_mf, seed=12000, we find 4 checkpoints and the best success rate is 0.794
# Path:
# /home/zhenghao/CoPO/copo_code/copo/1012_ccppo_mf/CCPPOTrainerForMAOurEnvironment_CCMultiAgentIntersectionEnv_2700f_00047_47_counterfactual=True,env=CCMultiAgentIntersectionEnv,sta_2022-10-12_21-48-32/checkpoint_625/checkpoint-625
#
#
# For env=PGMap, algo=1003_copo_formal, seed=12000, we find 5 checkpoints and the best success rate is 0.626
# Path:
# /home/zhpeng/CoPO/copo_code/copo/1003_copo/CoPO_CCMultiAgentMetaDrive_647d3_00047_47_env=CCMultiAgentMetaDrive,start_seed=12000,seed=0,use_centralized_critic=False,use_distr_2022-10-05_17-55-13/checkpoint_625/checkpoint-625
#
#
# For env=PGMap, algo=1003_ippo, seed=12000, we find 3 checkpoints and the best success rate is 0.541
# Path:
# /home/zhenghao/CoPO/copo_code/copo/1003_ippo/IPPO_MultiAgentMetaDrive_ad347_00047_47_env=MultiAgentMetaDrive,start_seed=12000,seed=0_2022-10-04_02-07-46/checkpoint_625/checkpoint-625
#
#
# For env=PGMap, algo=1011_ccppo_concat, seed=12000, we find 4 checkpoints and the best success rate is 0.317
# Path:
# /home/zhenghao/CoPO/copo_code/copo/1011_ccppo_concat/CCPPOTrainerForMAOurEnvironment_CCMultiAgentMetaDrive_8533d_00045_45_counterfactual=True,env=CCMultiAgentMetaDrive,start_seed=1200_2022-10-11_19-57-09/checkpoint_625/checkpoint-625
#
#
# For env=PGMap, algo=1012_ccppo_mf, seed=12000, we find 3 checkpoints and the best success rate is 0.098
# Path:
# /home/zhenghao/CoPO/copo_code/copo/1012_ccppo_mf/CCPPOTrainerForMAOurEnvironment_CCMultiAgentMetaDrive_2700f_00045_45_counterfactual=True,env=CCMultiAgentMetaDrive,start_seed=1200_2022-10-12_21-44-01/checkpoint_625/checkpoint-625
#
#
# For env=Parking, algo=1003_copo_formal, seed=12000, we find 5 checkpoints and the best success rate is 0.282
# Path:
# /home/zhpeng/CoPO/copo_code/copo/1003_copo/CoPO_CCMultiAgentParkingLotEnv_647d3_00042_42_env=CCMultiAgentParkingLotEnv,start_seed=12000,seed=0,use_centralized_critic=False,u_2022-10-05_15-51-17/checkpoint_625/checkpoint-625
#
#
# For env=Parking, algo=1003_ippo, seed=12000, we find 4 checkpoints and the best success rate is 0.272
# Path:
# /home/zhenghao/CoPO/copo_code/copo/1003_ippo/IPPO_MultiAgentParkingLotEnv_ad347_00042_42_env=MultiAgentParkingLotEnv,start_seed=12000,seed=0_2022-10-04_01-08-20/checkpoint_625/checkpoint-625
#
#
# For env=Parking, algo=1011_ccppo_concat, seed=12000, we find 4 checkpoints and the best success rate is 0.252
# Path:
# /home/zhenghao/CoPO/copo_code/copo/1011_ccppo_concat/CCPPOTrainerForMAOurEnvironment_CCMultiAgentParkingLotEnv_8533d_00042_42_counterfactual=True,env=CCMultiAgentParkingLotEnv,start_s_2022-10-11_18-43-10/checkpoint_625/checkpoint-625
#
#
# For env=Parking, algo=1012_ccppo_mf, seed=12000, we find 4 checkpoints and the best success rate is 0.294
# Path:
# /home/zhenghao/CoPO/copo_code/copo/1012_ccppo_mf/CCPPOTrainerForMAOurEnvironment_CCMultiAgentParkingLotEnv_2700f_00042_42_counterfactual=True,env=CCMultiAgentParkingLotEnv,start_s_2022-10-12_21-07-23/checkpoint_625/checkpoint-625
#
#
# For env=Round, algo=1003_copo_formal, seed=12000, we find 5 checkpoints and the best success rate is 0.860
# Path:
# /home/zhpeng/CoPO/copo_code/copo/1003_copo/CoPO_CCMultiAgentRoundaboutEnv_647d3_00043_43_env=CCMultiAgentRoundaboutEnv,start_seed=12000,seed=0,use_centralized_critic=False,u_2022-10-05_15-58-49/checkpoint_625/checkpoint-625
#
#
# For env=Round, algo=1003_ippo, seed=12000, we find 4 checkpoints and the best success rate is 0.770
# Path:
# /home/zhenghao/CoPO/copo_code/copo/1003_ippo/IPPO_MultiAgentRoundaboutEnv_ad347_00046_46_env=MultiAgentRoundaboutEnv,start_seed=12000,seed=0_2022-10-04_01-33-26/checkpoint_625/checkpoint-625
#
#
# For env=Round, algo=1011_ccppo_concat, seed=12000, we find 3 checkpoints and the best success rate is 0.753
# Path:
# /home/zhenghao/CoPO/copo_code/copo/1011_ccppo_concat/CCPPOTrainerForMAOurEnvironment_CCMultiAgentRoundaboutEnv_8533d_00043_43_counterfactual=True,env=CCMultiAgentRoundaboutEnv,start_s_2022-10-11_18-55-17/checkpoint_625/checkpoint-625
#
#
# For env=Round, algo=1012_ccppo_mf, seed=12000, we find 3 checkpoints and the best success rate is 0.834
# Path:
# /home/zhenghao/CoPO/copo_code/copo/1012_ccppo_mf/CCPPOTrainerForMAOurEnvironment_CCMultiAgentRoundaboutEnv_2700f_00043_43_counterfactual=True,env=CCMultiAgentRoundaboutEnv,start_s_2022-10-12_21-12-54/checkpoint_625/checkpoint-625
#
#
# For env=Tollgate, algo=1003_copo_formal, seed=12000, we find 6 checkpoints and the best success rate is 0.641
# Path:
# /home/zhpeng/CoPO/copo_code/copo/1003_copo/CoPO_CCMultiAgentTollgateEnv_647d3_00044_44_env=CCMultiAgentTollgateEnv,start_seed=12000,seed=0,use_centralized_critic=False,use_d_2022-10-05_16-07-14/checkpoint_625/checkpoint-625
#
#
# For env=Tollgate, algo=1003_ippo, seed=12000, we find 4 checkpoints and the best success rate is 0.095
# Path:
# /home/zhenghao/CoPO/copo_code/copo/1003_ippo/IPPO_MultiAgentTollgateEnv_ad347_00044_44_env=MultiAgentTollgateEnv,start_seed=12000,seed=0_2022-10-04_01-24-49/checkpoint_625/checkpoint-625
#
#
# For env=Tollgate, algo=1011_ccppo_concat, seed=12000, we find 3 checkpoints and the best success rate is 0.111
# Path:
# /home/zhenghao/CoPO/copo_code/copo/1011_ccppo_concat/CCPPOTrainerForMAOurEnvironment_CCMultiAgentTollgateEnv_8533d_00046_46_counterfactual=True,env=CCMultiAgentTollgateEnv,start_seed=_2022-10-11_19-57-21/checkpoint_625/checkpoint-625
#
#
# For env=Tollgate, algo=1012_ccppo_mf, seed=12000, we find 3 checkpoints and the best success rate is 0.490
# Path:
# /home/zhenghao/CoPO/copo_code/copo/1012_ccppo_mf/CCPPOTrainerForMAOurEnvironment_CCMultiAgentTollgateEnv_2700f_00046_46_counterfactual=True,env=CCMultiAgentTollgateEnv,start_seed=_2022-10-12_21-47-47/checkpoint_625/checkpoint-625
